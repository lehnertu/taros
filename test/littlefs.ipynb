# %% [markdown]
# # Test of the littlefs file system on SD card
#
# installed with `pip install littlefs-python`
#
# --> Successfully installed littlefs-python-0.8.0

# %%
! lsblk | grep mmc
# Out:
# mmcblk0 179:0    0   7,4G  0 disk

# %%
! chmod a+rw /dev/mmcblk0
# Out:
# chmod: Beim Setzen der Zugriffsrechte für '/dev/mmcblk0': Vorgang nicht zulässig

# %%
import littlefs
dir(littlefs)
# Out:
# ['DistributionNotFound',
#  'FileHandle',
#  'IO',
#  'Iterator',
#  'List',
#  'LittleFS',
#  'LittleFSError',
#  'Optional',
#  'TYPE_CHECKING',
#  'Tuple',
#  'Union',
#  '__LFS_DISK_VERSION__',
#  '__LFS_VERSION__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__path__',
#  '__spec__',
#  '__version__',
#  '_typ_to_uint8',
#  'context',
#  'errors',
#  'get_distribution',
#  'io',
#  'lfs',
#  'warnings']

# %%
help(littlefs.IO)
# Out:
# Help on class IO in module typing:
#
# class IO(Generic)
#  |  Generic base class for TextIO and BinaryIO.
#  |
#  |  This is an abstract, generic version of the return of open().
#  |
#  |  NOTE: This does not distinguish between the different possible
#  |  classes (text vs. binary, read vs. write vs. read/write,
#  |  append-only, unbuffered).  The TextIO and BinaryIO subclasses
#  |  below capture the distinctions between text vs. binary, which is
#  |  pervasive in the interface; however we currently do not offer a
#  |  way to track the other distinctions in the type system.
#  |
#  |  Method resolution order:
#  |      IO
#  |      Generic
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __enter__(self) -> 'IO[AnyStr]'
#  |
#  |  __exit__(self, type, value, traceback) -> None
#  |
#  |  close(self) -> None
#  |
#  |  fileno(self) -> int
#  |
#  |  flush(self) -> None
#  |
#  |  isatty(self) -> bool
#  |
#  |  read(self, n: int = -1) -> ~AnyStr
#  |
# ...

# %%
from littlefs import LittleFS

# %%
help(LittleFS)
# Out:
# Help on class LittleFS in module littlefs:
#
# class LittleFS(builtins.object)
#  |  LittleFS(context: Optional[ForwardRef('UserContext')] = None, mount=True, **kwargs) -> None
#  |
#  |  Littlefs file system
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, context: Optional[ForwardRef('UserContext')] = None, mount=True, **kwargs) -> None
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  format(self) -> int
#  |      Format the underlying buffer
#  |
#  |  fs_grow(self, block_count: int) -> int
#  |
#  |  fs_mkconsistent(self) -> int
#  |      Attempt to make the filesystem consistent and ready for writing
#  |
#  |  fs_stat(self) -> 'LFSFSStat'
#  |      Get the status of the filesystem
#  |
#  |  getattr(self, path: str, typ: Union[str, bytes, int]) -> bytes
#  |
#  |  listdir(self, path='.') -> List[str]
#  |      List directory content
#  |
#  |      List the content of a directory. This function uses :meth:`scandir`
# ...

# %%
from littlefs import lfs

# %%
help(lfs)
# Out:
# Help on module littlefs.lfs in littlefs:
#
# NAME
#     littlefs.lfs
#
# CLASSES
#     builtins.object
#         LFSConfig
#         LFSDirectory
#         LFSFile
#         LFSFilesystem
#     enum.IntFlag(builtins.int, enum.Flag)
#         LFSFileFlag
#
#     class LFSConfig(builtins.object)
#      |  LFSConfig(context=None, int block_size: int = 128, *, int block_count: int = 64, int read_size: int = 0, int prog_size: int = 0, int block_cycles: int = -1, int cache_size: int = 0, int lookahead_size: int = 8, int name_max: int = 255, int file_max: int = 0, int attr_max: int = 0, int metadata_max: int = 0, int disk_version: int = 0)
#      |
#      |  Methods defined here:
#      |
#      |  __init__(...)
#      |      LittleFS Configuration.
#      |
#      |      If the block size and count is not given, create a
#      |      small memory with minimal block size and 8KB size.
#      |
#      |      Parameters
#      |      ----------
#      |      block_size : int
# ...

# %%
help(lfs.LFSFilesystem)
# Out:
# Help on class LFSFilesystem in module littlefs.lfs:
#
# class LFSFilesystem(builtins.object)
#  |  Methods defined here:
#  |
#  |  __reduce__ = __reduce_cython__(...)
#  |      LFSFilesystem.__reduce_cython__(self)
#  |
#  |  __setstate__ = __setstate_cython__(...)
#  |      LFSFilesystem.__setstate_cython__(self, __pyx_state)
#  |
#  |  ----------------------------------------------------------------------
#  |  Static methods defined here:
#  |
#  |  __new__(*args, **kwargs) from builtins.type
#  |      Create and return a new object.  See help(type) for accurate signature.
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  block_count
#  |      LFSFilesystem.block_count: lfs_size_t

# %%
help(lfs.LFSConfig)
# Out:
# Help on class LFSConfig in module littlefs.lfs:
#
# class LFSConfig(builtins.object)
#  |  LFSConfig(context=None, int block_size: int = 128, *, int block_count: int = 64, int read_size: int = 0, int prog_size: int = 0, int block_cycles: int = -1, int cache_size: int = 0, int lookahead_size: int = 8, int name_max: int = 255, int file_max: int = 0, int attr_max: int = 0, int metadata_max: int = 0, int disk_version: int = 0)
#  |
#  |  Methods defined here:
#  |
#  |  __init__(...)
#  |      LittleFS Configuration.
#  |
#  |      If the block size and count is not given, create a
#  |      small memory with minimal block size and 8KB size.
#  |
#  |      Parameters
#  |      ----------
#  |      block_size : int
#  |          Defaults to 128.
#  |      block_count : int
#  |          Number of blocks in the filesystem.
#  |          If set to 0, attempt to autodetect ``block_count`` from filesystem.
#  |          Defaults to 64.
#  |      read_size: int
# ...
